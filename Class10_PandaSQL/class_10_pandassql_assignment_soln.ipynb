# %% [markdown]
# ## Pandas SQL Assignment

# %% [markdown]
# ### Problem statement 1:

# %% [markdown]
# Read the following data set:
#
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/
#
# Rename the columns as per the description from this file:
#
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.names

# %%
# Imports
import numpy as np
import pandas as pd
from pandasql import sqldf

# %%
adult_df = pd.read_csv('adult\\adult_data.csv')
adult_df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'Weights']
adult_df.head(2)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
#
#         marital-status          occupation    relationship    race    sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country Weights
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K

# %% [markdown]
# ### Create a sql db from adult dataset and name it sqladb

# %%
sqladb = lambda q: sqldf(q, globals())

# %% [markdown]
# #### Q1. Select 10 records from the adult sqladb

# %%
sql_select_adult_10 = "SELECT * FROM adult_df LIMIT 10;"
sqladb(sql_select_adult_10)
# Out:
#    age          workclass  fnlwgt      education  education-num  \
# 0   50   Self-emp-not-inc   83311      Bachelors             13
# 1   38            Private  215646        HS-grad              9
# 2   53            Private  234721           11th              7
# 3   28            Private  338409      Bachelors             13
# 4   37            Private  284582        Masters             14
# 5   49            Private  160187            9th              5
# 6   52   Self-emp-not-inc  209642        HS-grad              9
# 7   31            Private   45781        Masters             14
# 8   42            Private  159449      Bachelors             13
# 9   37            Private  280464   Some-college             10
#
#            marital-status          occupation    relationship    race  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# 2      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3      Married-civ-spouse      Prof-specialty            Wife   Black
# 4      Married-civ-spouse     Exec-managerial            Wife   White
# 5   Married-spouse-absent       Other-service   Not-in-family   Black
# 6      Married-civ-spouse     Exec-managerial         Husband   White
# 7           Never-married      Prof-specialty   Not-in-family   White
# 8      Married-civ-spouse     Exec-managerial         Husband   White
# 9      Married-civ-spouse     Exec-managerial         Husband   Black
#
#        sex  capital-gain  capital-loss  hours-per-week  native-country Weights
# 0     Male             0             0              13   United-States   <=50K
# 1     Male             0             0              40   United-States   <=50K
# 2     Male             0             0              40   United-States   <=50K
# 3   Female             0             0              40            Cuba   <=50K
# 4   Female             0             0              40   United-States   <=50K
# 5   Female             0             0              16         Jamaica   <=50K
# 6     Male             0             0              45   United-States    >50K
# 7   Female         14084             0              50   United-States    >50K
# 8     Male          5178             0              40   United-States    >50K
# 9     Male             0             0              80   United-States    >50K

# %% [markdown]
# #### Q2. Show me the average hours per week of all men who are working in private sector

# %%
sql_select_avg_wrk_hr_4men = "SELECT avg([hours-per-week]) as [avg-work-hrs] FROM adult_df WHERE sex=' Male' AND workclass=' Private';"
sqladb(sql_select_avg_wrk_hr_4men)
# Out:
#    avg-work-hrs
# 0     42.221226

# %% [markdown]
# #### Q3. Show me the frequency table for education, occupation and relationship, separately

# %%
# Frequency of Education
print('Frequency of Education:')
sql_select_freq_education = "SELECT education, COUNT(*) as frequency FROM adult_df GROUP BY education ORDER BY COUNT(*) DESC;"
sqladb(sql_select_freq_education)
# Out:
# Frequency of Education:
#         education  frequency
# 0         HS-grad      10501
# 1    Some-college       7291
# 2       Bachelors       5354
# 3         Masters       1723
# 4       Assoc-voc       1382
# 5            11th       1175
# 6      Assoc-acdm       1067
# 7            10th        933
# 8         7th-8th        646
# 9     Prof-school        576
# 10            9th        514
# 11           12th        433
# 12      Doctorate        413
# 13        5th-6th        333
# 14        1st-4th        168
# 15      Preschool         51

# %%
# Frequency of Occupation
print('Frequency of Occupation:')
sql_select_freq_occupation = "SELECT occupation, COUNT(*) as frequency FROM adult_df GROUP BY occupation ORDER BY COUNT(*) DESC;"
sqladb(sql_select_freq_occupation)
# Out:
# Frequency of Occupation:
#             occupation  frequency
# 0       Prof-specialty       4140
# 1         Craft-repair       4099
# 2      Exec-managerial       4066
# 3         Adm-clerical       3769
# 4                Sales       3650
# 5        Other-service       3295
# 6    Machine-op-inspct       2002
# 7                    ?       1843
# 8     Transport-moving       1597
# 9    Handlers-cleaners       1370
# 10     Farming-fishing        994
# 11        Tech-support        928
# 12     Protective-serv        649
# 13     Priv-house-serv        149
# 14        Armed-Forces          9

# %%
# Frequency of Relationship
print('Frequency of Relationship:')
sql_select_freq_relationship = "SELECT relationship, COUNT(*) as frequency FROM adult_df GROUP BY relationship ORDER BY COUNT(*) DESC;"
sqladb(sql_select_freq_relationship)
# Out:
# Frequency of Relationship:
#       relationship  frequency
# 0          Husband      13193
# 1    Not-in-family       8304
# 2        Own-child       5068
# 3        Unmarried       3446
# 4             Wife       1568
# 5   Other-relative        981

# %% [markdown]
# #### Q4. Are there any people who are married, working in private sector and having a master’s degree

# %%
sql_select_mrd_pvt_masters = "SELECT * FROM adult_df WHERE relationship IN (' Husband', ' Wife') AND workclass=' Private' AND education=' Masters';"
sqladb(sql_select_mrd_pvt_masters)
# Out:
#      age workclass  fnlwgt education  education-num       marital-status  \
# 0     37   Private  284582   Masters             14   Married-civ-spouse
# 1     33   Private  202051   Masters             14   Married-civ-spouse
# 2     76   Private  124191   Masters             14   Married-civ-spouse
# 3     31   Private   99928   Masters             14   Married-civ-spouse
# 4     34   Private  142897   Masters             14   Married-civ-spouse
# 5     62   Private  270092   Masters             14   Married-civ-spouse
# 6     41   Private  445382   Masters             14   Married-civ-spouse
# 7     33   Private  208405   Masters             14   Married-civ-spouse
# 8     49   Private  192776   Masters             14   Married-civ-spouse
# 9     51   Private  410114   Masters             14   Married-civ-spouse
# 10    31   Private  118710   Masters             14   Married-civ-spouse
# 11    34   Private   73585   Masters             14   Married-civ-spouse
# 12    40   Private  170108   Masters             14   Married-civ-spouse
# 13    43   Private  158926   Masters             14   Married-civ-spouse
# 14    51   Private  138022   Masters             14   Married-civ-spouse
# 15    43   Private  227065   Masters             14   Married-civ-spouse
# 16    38   Private  173208   Masters             14   Married-civ-spouse
# 17    33   Private  354573   Masters             14   Married-civ-spouse
# 18    59   Private  151616   Masters             14   Married-civ-spouse
# 19    38   Private   22245   Masters             14   Married-civ-spouse
# 20    46   Private  279661   Masters             14   Married-civ-spouse
# 21    65   Private  198766   Masters             14   Married-civ-spouse
# 22    55   Private   98361   Masters             14   Married-civ-spouse
# 23    45   Private   46406   Masters             14   Married-civ-spouse
# 24    48   Private  126754   Masters             14   Married-civ-spouse
# 25    54   Private  177927   Masters             14   Married-civ-spouse
# 26    43   Private  201723   Masters             14   Married-civ-spouse
# 27    41   Private  233955   Masters             14   Married-civ-spouse
# 28    49   Private  186078   Masters             14   Married-civ-spouse
# 29    39   Private   79331   Masters             14   Married-civ-spouse
# ..   ...       ...     ...       ...            ...                  ...
# 498   23   Private  143003   Masters             14   Married-civ-spouse
# 499   50   Private  201882   Masters             14   Married-civ-spouse
# 500   44   Private  267717   Masters             14   Married-civ-spouse
# 501   30   Private  182771   Masters             14   Married-civ-spouse
# 502   39   Private  198841   Masters             14   Married-civ-spouse
# 503   53   Private   53197   Masters             14   Married-civ-spouse
# 504   55   Private   70088   Masters             14   Married-civ-spouse
# 505   36   Private  199346   Masters             14   Married-civ-spouse
# 506   30   Private  378009   Masters             14   Married-civ-spouse
# 507   35   Private   75855   Masters             14   Married-civ-spouse
# 508   59   Private   59469   Masters             14   Married-civ-spouse
# 509   39   Private   72338   Masters             14   Married-civ-spouse
# 510   50   Private  176157   Masters             14   Married-civ-spouse
# 511   30   Private  341051   Masters             14   Married-civ-spouse
# 512   43   Private  346321   Masters             14   Married-civ-spouse
# 513   47   Private  155664   Masters             14   Married-civ-spouse
# 514   48   Private  379883   Masters             14   Married-civ-spouse
# 515   49   Private  123681   Masters             14   Married-civ-spouse
# 516   43   Private  174295   Masters             14   Married-civ-spouse
# 517   32   Private  313835   Masters             14   Married-civ-spouse
# 518   40   Private  137225   Masters             14   Married-civ-spouse
# 519   25   Private  178025   Masters             14   Married-civ-spouse
# 520   31   Private  183801   Masters             14   Married-civ-spouse
# 521   61   Private  232719   Masters             14   Married-civ-spouse
# 522   41   Private  122215   Masters             14   Married-civ-spouse
# 523   33   Private  139057   Masters             14   Married-civ-spouse
# 524   34   Private   30673   Masters             14   Married-civ-spouse
# 525   41   Private  201495   Masters             14   Married-civ-spouse
# 526   46   Private   42972   Masters             14   Married-civ-spouse
# 527   53   Private  321865   Masters             14   Married-civ-spouse
#
#              occupation relationship                 race      sex  \
# 0       Exec-managerial         Wife                White   Female
# 1        Prof-specialty      Husband                White     Male
# 2       Exec-managerial      Husband                White     Male
# 3        Prof-specialty         Wife                White   Female
# 4       Exec-managerial      Husband   Asian-Pac-Islander     Male
# 5        Prof-specialty      Husband                White     Male
# 6       Exec-managerial      Husband                White     Male
# 7        Prof-specialty      Husband                White     Male
# 8       Exec-managerial      Husband                White     Male
# 9          Craft-repair      Husband                White     Male
# 10         Tech-support      Husband                White     Male
# 11       Prof-specialty      Husband                White     Male
# 12       Prof-specialty      Husband                White     Male
# 13       Prof-specialty         Wife   Asian-Pac-Islander   Female
# 14      Exec-managerial      Husband                White     Male
# 15      Exec-managerial      Husband                White     Male
# 16       Prof-specialty      Husband                White     Male
# 17       Prof-specialty      Husband                White     Male
# 18       Prof-specialty      Husband                White     Male
# 19     Transport-moving      Husband                White     Male
# 20       Prof-specialty      Husband                Black     Male
# 21                Sales      Husband                White     Male
# 22       Prof-specialty      Husband                White     Male
# 23       Prof-specialty      Husband                White     Male
# 24       Prof-specialty      Husband                White     Male
# 25       Prof-specialty      Husband                White     Male
# 26      Exec-managerial      Husband                White     Male
# 27       Prof-specialty      Husband   Asian-Pac-Islander     Male
# 28       Prof-specialty         Wife                White   Female
# 29      Exec-managerial      Husband   Asian-Pac-Islander     Male
# ..                  ...          ...                  ...      ...
# 498      Prof-specialty      Husband   Asian-Pac-Islander     Male
# 499   Machine-op-inspct      Husband                White     Male
# 500      Prof-specialty      Husband                White     Male
# 501      Prof-specialty      Husband   Asian-Pac-Islander     Male
# 502      Prof-specialty      Husband                White     Male
# 503      Prof-specialty      Husband                White     Male
# 504      Prof-specialty      Husband                White     Male
# 505      Prof-specialty         Wife                White   Female
# 506     Exec-managerial      Husband                White     Male
# 507      Prof-specialty      Husband                Black     Male
# 508        Tech-support      Husband                White     Male
# 509      Prof-specialty      Husband   Asian-Pac-Islander     Male
# 510     Exec-managerial      Husband                White     Male
# 511     Exec-managerial      Husband                White     Male
# 512      Prof-specialty      Husband                White     Male
# 513     Exec-managerial      Husband                White     Male
# 514      Prof-specialty      Husband                White     Male
# 515      Prof-specialty      Husband                White     Male
# 516      Prof-specialty      Husband                White     Male
# 517      Prof-specialty      Husband                White     Male
# 518     Exec-managerial      Husband                White     Male
# 519      Prof-specialty      Husband                White     Male
# 520      Prof-specialty      Husband                White     Male
# 521      Prof-specialty      Husband                White     Male
# 522      Prof-specialty      Husband                White     Male
# 523        Tech-support      Husband   Asian-Pac-Islander     Male
# 524      Prof-specialty      Husband                White     Male
# 525     Exec-managerial      Husband                White     Male
# 526      Prof-specialty         Wife                White   Female
# 527     Exec-managerial      Husband                White     Male
#
#      capital-gain  capital-loss  hours-per-week  native-country Weights
# 0               0             0              40   United-States   <=50K
# 1               0             0              50   United-States   <=50K
# 2               0             0              40   United-States    >50K
# 3               0             0              50   United-States   <=50K
# 4            7298             0              35          Taiwan    >50K
# 5               0             0              40   United-States    >50K
# 6               0          1977              65   United-States    >50K
# 7               0             0              50   United-States    >50K
# 8               0          1977              45   United-States    >50K
# 9               0             0              40   United-States    >50K
# 10              0          1902              40   United-States    >50K
# 11              0             0              40               ?   <=50K
# 12              0             0              40   United-States   <=50K
# 13              0             0              50           South   <=50K
# 14              0             0              60   United-States    >50K
# 15              0             0              43   United-States    >50K
# 16              0             0              25   United-States   <=50K
# 17          15024             0              44   United-States    >50K
# 18              0             0              55   United-States   <=50K
# 19              0             0              72               ?    >50K
# 20              0             0              35   United-States   <=50K
# 21          20051             0              40   United-States    >50K
# 22          15024             0              50               ?    >50K
# 23              0             0              36         England    >50K
# 24          15024             0              40   United-States    >50K
# 25              0             0              60   United-States   <=50K
# 26              0          1902              40   United-States    >50K
# 27              0             0              45           China    >50K
# 28              0             0              50   United-States    >50K
# 29          15024             0              40   United-States    >50K
# ..            ...           ...             ...             ...     ...
# 498             0          1887              50           India    >50K
# 499             0             0              30   United-States   <=50K
# 500             0             0              42   United-States    >50K
# 501             0             0              40   United-States    >50K
# 502          7688             0              45   United-States    >50K
# 503          3103             0              40   United-States    >50K
# 504             0             0              40   United-States    >50K
# 505             0             0              50   United-States    >50K
# 506             0             0              50   United-States    >50K
# 507          7298             0              40               ?    >50K
# 508             0             0              40            Iran   <=50K
# 509             0             0              40     Philippines    >50K
# 510             0             0              50   United-States    >50K
# 511         15024             0              60   United-States    >50K
# 512             0             0              45   United-States    >50K
# 513         99999             0              55   United-States    >50K
# 514             0             0              40            Cuba    >50K
# 515             0             0              43   United-States    >50K
# 516             0             0              55   United-States   <=50K
# 517             0             0              40   United-States    >50K
# 518             0             0              40   United-States    >50K
# 519             0             0              40   United-States   <=50K
# 520             0          1902              43   United-States    >50K
# 521             0             0              50   United-States   <=50K
# 522         15024             0              40   United-States    >50K
# 523             0             0              50   United-States    >50K
# 524             0             0              55   United-States   <=50K
# 525             0             0              40   United-States    >50K
# 526             0             0              22   United-States    >50K
# 527             0             0              40   United-States    >50K
#
# [528 rows x 15 columns]

# %% [markdown]
# #### Q5. What is the average, minimum and maximum age group for people working in different sectors

# %%
sql_select_occupation_age_dist = "SELECT occupation, avg(age) as [avg-age], min(age) as [min-age], max(age) as [max-age] FROM adult_df GROUP BY occupation;"
sqladb(sql_select_occupation_age_dist)
# Out:
#             occupation    avg-age  min-age  max-age
# 0                    ?  40.882800       17       90
# 1         Adm-clerical  36.963916       17       90
# 2         Armed-Forces  30.222222       23       46
# 3         Craft-repair  39.031471       17       90
# 4      Exec-managerial  42.169208       17       90
# 5      Farming-fishing  41.211268       17       90
# 6    Handlers-cleaners  32.165693       17       90
# 7    Machine-op-inspct  37.715285       17       90
# 8        Other-service  34.949621       17       90
# 9      Priv-house-serv  41.724832       17       81
# 10      Prof-specialty  40.517633       17       90
# 11     Protective-serv  38.953775       17       90
# 12               Sales  37.353973       17       90
# 13        Tech-support  37.022629       17       73
# 14    Transport-moving  40.197871       17       90

# %% [markdown]
# #### Q6. Calculate age distribution by country

# %%
sql_select_age_distrib_by_country = """SELECT 
    [native-country],
    Round(Round((count(age)*100), 5) / Round((select count(age) from adult_df), 5), 5) as 'Age Distribution'
    FROM adult_df GROUP BY [native-country] order by count(age) desc;"""

sqladb(sql_select_age_distrib_by_country)
# Out:
#                  native-country  Age Distribution
# 0                 United-States          89.58538
# 1                        Mexico           1.97482
# 2                             ?           1.79054
# 3                   Philippines           0.60811
# 4                       Germany           0.42076
# 5                        Canada           0.37162
# 6                   Puerto-Rico           0.35012
# 7                   El-Salvador           0.32555
# 8                         India           0.30713
# 9                          Cuba           0.29177
# 10                      England           0.27641
# 11                      Jamaica           0.24877
# 12                        South           0.24570
# 13                        China           0.23034
# 14                        Italy           0.22420
# 15           Dominican-Republic           0.21499
# 16                      Vietnam           0.20577
# 17                    Guatemala           0.19656
# 18                        Japan           0.19042
# 19                       Poland           0.18428
# 20                     Columbia           0.18120
# 21                       Taiwan           0.15663
# 22                        Haiti           0.13514
# 23                         Iran           0.13206
# 24                     Portugal           0.11364
# 25                    Nicaragua           0.10442
# 26                         Peru           0.09521
# 27                       France           0.08907
# 28                       Greece           0.08907
# 29                      Ecuador           0.08600
# 30                      Ireland           0.07371
# 31                         Hong           0.06143
# 32                     Cambodia           0.05835
# 33              Trinadad&Tobago           0.05835
# 34                         Laos           0.05528
# 35                     Thailand           0.05528
# 36                   Yugoslavia           0.04914
# 37   Outlying-US(Guam-USVI-etc)           0.04300
# 38                     Honduras           0.03993
# 39                      Hungary           0.03993
# 40                     Scotland           0.03686
# 41           Holand-Netherlands           0.00307

# %% [markdown]
# #### Q7. Compute a new column as 'Net-Capital-Gain' from the two columns 'capital-gain' and 'capital-loss'

# %%
sql_select_calc_Net_Capital_Gain = "SELECT age, workclass, fnlwgt, education, [education-num], [marital-status], occupation, relationship, race, sex, [capital-gain], [capital-loss], ([capital-gain]-[capital-loss]) as [Net-Capital-Gain], [hours-per-week], [native-country], Weights FROM adult_df;"
sqladb(sql_select_calc_Net_Capital_Gain)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 3       28            Private  338409      Bachelors             13
# 4       37            Private  284582        Masters             14
# 5       49            Private  160187            9th              5
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 7       31            Private   45781        Masters             14
# 8       42            Private  159449      Bachelors             13
# 9       37            Private  280464   Some-college             10
# 10      30          State-gov  141297      Bachelors             13
# 11      23            Private  122272      Bachelors             13
# 12      32            Private  205019     Assoc-acdm             12
# 13      40            Private  121772      Assoc-voc             11
# 14      34            Private  245487        7th-8th              4
# 15      25   Self-emp-not-inc  176756        HS-grad              9
# 16      32            Private  186824        HS-grad              9
# 17      38            Private   28887           11th              7
# 18      43   Self-emp-not-inc  292175        Masters             14
# 19      40            Private  193524      Doctorate             16
# 20      54            Private  302146        HS-grad              9
# 21      35        Federal-gov   76845            9th              5
# 22      43            Private  117037           11th              7
# 23      59            Private  109015        HS-grad              9
# 24      56          Local-gov  216851      Bachelors             13
# 25      19            Private  168294        HS-grad              9
# 26      54                  ?  180211   Some-college             10
# 27      39            Private  367260        HS-grad              9
# 28      49            Private  193366        HS-grad              9
# 29      23          Local-gov  190709     Assoc-acdm             12
# ...    ...                ...     ...            ...            ...
# 32530   30                  ?   33811      Bachelors             13
# 32531   34            Private  204461      Doctorate             16
# 32532   54            Private  337992      Bachelors             13
# 32533   37            Private  179137   Some-college             10
# 32534   22            Private  325033           12th              8
# 32535   34            Private  160216      Bachelors             13
# 32536   30            Private  345898        HS-grad              9
# 32537   38            Private  139180      Bachelors             13
# 32538   71                  ?  287372      Doctorate             16
# 32539   45          State-gov  252208        HS-grad              9
# 32540   41                  ?  202822        HS-grad              9
# 32541   72                  ?  129912        HS-grad              9
# 32542   45          Local-gov  119199     Assoc-acdm             12
# 32543   31            Private  199655        Masters             14
# 32544   39          Local-gov  111499     Assoc-acdm             12
# 32545   37            Private  198216     Assoc-acdm             12
# 32546   43            Private  260761        HS-grad              9
# 32547   65   Self-emp-not-inc   99359    Prof-school             15
# 32548   43          State-gov  255835   Some-college             10
# 32549   43   Self-emp-not-inc   27242   Some-college             10
# 32550   32            Private   34066           10th              6
# 32551   43            Private   84661      Assoc-voc             11
# 32552   32            Private  116138        Masters             14
# 32553   53            Private  321865        Masters             14
# 32554   22            Private  310152   Some-college             10
# 32555   27            Private  257302     Assoc-acdm             12
# 32556   40            Private  154374        HS-grad              9
# 32557   58            Private  151910        HS-grad              9
# 32558   22            Private  201490        HS-grad              9
# 32559   52       Self-emp-inc  287927        HS-grad              9
#
#                marital-status          occupation     relationship  \
# 0          Married-civ-spouse     Exec-managerial          Husband
# 1                    Divorced   Handlers-cleaners    Not-in-family
# 2          Married-civ-spouse   Handlers-cleaners          Husband
# 3          Married-civ-spouse      Prof-specialty             Wife
# 4          Married-civ-spouse     Exec-managerial             Wife
# 5       Married-spouse-absent       Other-service    Not-in-family
# 6          Married-civ-spouse     Exec-managerial          Husband
# 7               Never-married      Prof-specialty    Not-in-family
# 8          Married-civ-spouse     Exec-managerial          Husband
# 9          Married-civ-spouse     Exec-managerial          Husband
# 10         Married-civ-spouse      Prof-specialty          Husband
# 11              Never-married        Adm-clerical        Own-child
# 12              Never-married               Sales    Not-in-family
# 13         Married-civ-spouse        Craft-repair          Husband
# 14         Married-civ-spouse    Transport-moving          Husband
# 15              Never-married     Farming-fishing        Own-child
# 16              Never-married   Machine-op-inspct        Unmarried
# 17         Married-civ-spouse               Sales          Husband
# 18                   Divorced     Exec-managerial        Unmarried
# 19         Married-civ-spouse      Prof-specialty          Husband
# 20                  Separated       Other-service        Unmarried
# 21         Married-civ-spouse     Farming-fishing          Husband
# 22         Married-civ-spouse    Transport-moving          Husband
# 23                   Divorced        Tech-support        Unmarried
# 24         Married-civ-spouse        Tech-support          Husband
# 25              Never-married        Craft-repair        Own-child
# 26         Married-civ-spouse                   ?          Husband
# 27                   Divorced     Exec-managerial    Not-in-family
# 28         Married-civ-spouse        Craft-repair          Husband
# 29              Never-married     Protective-serv    Not-in-family
# ...                       ...                 ...              ...
# 32530           Never-married                   ?    Not-in-family
# 32531      Married-civ-spouse      Prof-specialty          Husband
# 32532      Married-civ-spouse     Exec-managerial          Husband
# 32533                Divorced        Adm-clerical        Unmarried
# 32534           Never-married     Protective-serv        Own-child
# 32535           Never-married     Exec-managerial    Not-in-family
# 32536           Never-married        Craft-repair    Not-in-family
# 32537                Divorced      Prof-specialty        Unmarried
# 32538      Married-civ-spouse                   ?          Husband
# 32539               Separated        Adm-clerical        Own-child
# 32540               Separated                   ?    Not-in-family
# 32541      Married-civ-spouse                   ?          Husband
# 32542                Divorced      Prof-specialty        Unmarried
# 32543                Divorced       Other-service    Not-in-family
# 32544      Married-civ-spouse        Adm-clerical             Wife
# 32545                Divorced        Tech-support    Not-in-family
# 32546      Married-civ-spouse   Machine-op-inspct          Husband
# 32547           Never-married      Prof-specialty    Not-in-family
# 32548                Divorced        Adm-clerical   Other-relative
# 32549      Married-civ-spouse        Craft-repair          Husband
# 32550      Married-civ-spouse   Handlers-cleaners          Husband
# 32551      Married-civ-spouse               Sales          Husband
# 32552           Never-married        Tech-support    Not-in-family
# 32553      Married-civ-spouse     Exec-managerial          Husband
# 32554           Never-married     Protective-serv    Not-in-family
# 32555      Married-civ-spouse        Tech-support             Wife
# 32556      Married-civ-spouse   Machine-op-inspct          Husband
# 32557                 Widowed        Adm-clerical        Unmarried
# 32558           Never-married        Adm-clerical        Own-child
# 32559      Married-civ-spouse     Exec-managerial             Wife
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    White     Male             0             0
# 1                    White     Male             0             0
# 2                    Black     Male             0             0
# 3                    Black   Female             0             0
# 4                    White   Female             0             0
# 5                    Black   Female             0             0
# 6                    White     Male             0             0
# 7                    White   Female         14084             0
# 8                    White     Male          5178             0
# 9                    Black     Male             0             0
# 10      Asian-Pac-Islander     Male             0             0
# 11                   White   Female             0             0
# 12                   Black     Male             0             0
# 13      Asian-Pac-Islander     Male             0             0
# 14      Amer-Indian-Eskimo     Male             0             0
# 15                   White     Male             0             0
# 16                   White     Male             0             0
# 17                   White     Male             0             0
# 18                   White   Female             0             0
# 19                   White     Male             0             0
# 20                   Black   Female             0             0
# 21                   Black     Male             0             0
# 22                   White     Male             0          2042
# 23                   White   Female             0             0
# 24                   White     Male             0             0
# 25                   White     Male             0             0
# 26      Asian-Pac-Islander     Male             0             0
# 27                   White     Male             0             0
# 28                   White     Male             0             0
# 29                   White     Male             0             0
# ...                    ...      ...           ...           ...
# 32530   Asian-Pac-Islander   Female             0             0
# 32531                White     Male             0             0
# 32532   Asian-Pac-Islander     Male             0             0
# 32533                White   Female             0             0
# 32534                Black     Male             0             0
# 32535                White   Female             0             0
# 32536                Black     Male             0             0
# 32537                Black   Female         15020             0
# 32538                White     Male             0             0
# 32539                White   Female             0             0
# 32540                Black   Female             0             0
# 32541                White     Male             0             0
# 32542                White   Female             0             0
# 32543                Other   Female             0             0
# 32544                White   Female             0             0
# 32545                White   Female             0             0
# 32546                White     Male             0             0
# 32547                White     Male          1086             0
# 32548                White   Female             0             0
# 32549                White     Male             0             0
# 32550   Amer-Indian-Eskimo     Male             0             0
# 32551                White     Male             0             0
# 32552   Asian-Pac-Islander     Male             0             0
# 32553                White     Male             0             0
# 32554                White     Male             0             0
# 32555                White   Female             0             0
# 32556                White     Male             0             0
# 32557                White   Female             0             0
# 32558                White     Male             0             0
# 32559                White   Female         15024             0
#
#        Net-Capital-Gain  hours-per-week  native-country Weights
# 0                     0              13   United-States   <=50K
# 1                     0              40   United-States   <=50K
# 2                     0              40   United-States   <=50K
# 3                     0              40            Cuba   <=50K
# 4                     0              40   United-States   <=50K
# 5                     0              16         Jamaica   <=50K
# 6                     0              45   United-States    >50K
# 7                 14084              50   United-States    >50K
# 8                  5178              40   United-States    >50K
# 9                     0              80   United-States    >50K
# 10                    0              40           India    >50K
# 11                    0              30   United-States   <=50K
# 12                    0              50   United-States   <=50K
# 13                    0              40               ?    >50K
# 14                    0              45          Mexico   <=50K
# 15                    0              35   United-States   <=50K
# 16                    0              40   United-States   <=50K
# 17                    0              50   United-States   <=50K
# 18                    0              45   United-States    >50K
# 19                    0              60   United-States    >50K
# 20                    0              20   United-States   <=50K
# 21                    0              40   United-States   <=50K
# 22                -2042              40   United-States   <=50K
# 23                    0              40   United-States   <=50K
# 24                    0              40   United-States    >50K
# 25                    0              40   United-States   <=50K
# 26                    0              60           South    >50K
# 27                    0              80   United-States   <=50K
# 28                    0              40   United-States   <=50K
# 29                    0              52   United-States   <=50K
# ...                 ...             ...             ...     ...
# 32530                 0              99   United-States   <=50K
# 32531                 0              60   United-States    >50K
# 32532                 0              50           Japan    >50K
# 32533                 0              39   United-States   <=50K
# 32534                 0              35   United-States   <=50K
# 32535                 0              55   United-States    >50K
# 32536                 0              46   United-States   <=50K
# 32537             15020              45   United-States    >50K
# 32538                 0              10   United-States    >50K
# 32539                 0              40   United-States   <=50K
# 32540                 0              32   United-States   <=50K
# 32541                 0              25   United-States   <=50K
# 32542                 0              48   United-States   <=50K
# 32543                 0              30   United-States   <=50K
# 32544                 0              20   United-States    >50K
# 32545                 0              40   United-States   <=50K
# 32546                 0              40          Mexico   <=50K
# 32547              1086              60   United-States   <=50K
# 32548                 0              40   United-States   <=50K
# 32549                 0              50   United-States   <=50K
# 32550                 0              40   United-States   <=50K
# 32551                 0              45   United-States   <=50K
# 32552                 0              11          Taiwan   <=50K
# 32553                 0              40   United-States    >50K
# 32554                 0              40   United-States   <=50K
# 32555                 0              38   United-States   <=50K
# 32556                 0              40   United-States    >50K
# 32557                 0              40   United-States   <=50K
# 32558                 0              20   United-States   <=50K
# 32559             15024              40   United-States    >50K
#
# [32560 rows x 16 columns]
