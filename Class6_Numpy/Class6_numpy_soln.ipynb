# %% [markdown]
# ### Numpy: Assignment-1 Solution

# %%
import numpy as np

# %% [markdown]
# #### Problem Statement 1:
# Write a function so that the columns of the output matrix are powers of the input vector.
#
# The order of the powers is determined by the increasing boolean argument. Specifically, when increasing is False, the i-th output column is the input vector raised element-wise to the power of N - i - 1.
#
# **HINT:** Such a matrix with a geometric progression in each row is named for **Alexandre-Theophile Vandermonde**.

# %%
# Inputs
arr = np.array([1, 2, 3, 5])
N = 4
increasing = False

# %%
# Using Ternary Operator: [on_true] if [expression] else [on_false] 
# Example min = a if a < b else b 
vandermonde_matrix = np.column_stack([arr**(N-1-i) for i in range(N-1, -1, -1)] if increasing else [arr**(N-1-i) for i in range(N)])
print(vandermonde_matrix)
# Out:
# [[  1   1   1   1]
#  [  8   4   2   1]
#  [ 27   9   3   1]
#  [125  25   5   1]]

# %% [markdown]
# #### Problem Statement 2:
# Given a sequence of n values x1, x2, ..., xn and a window size k>0, the k-th moving average of the given sequence is defined as follows:
# * The moving average sequence has n-k+1 elements as shown below.
# * The moving averages with k=4 of a ten-value sequence (n=10) is shown below
#
# ![problem2_expected_op.JPG](attachment:problem2_expected_op.JPG)
#
# Thus, the moving average sequence has n-k+1=10-4+1=7 values.

# %%
# Function to find moving average
def moving_average(a, k) :
    ret = np.cumsum(a, dtype=float)
    # print(ret)
    ret[k:] = ret[k:] - ret[:-k]
    # print(ret)
    return ret[k - 1:] / k

l = [3, 5, 7, 2, 8, 10, 11, 65, 72, 81, 99, 100, 150]
k = 3
arr = np.array(l)
print('Moving average: ', moving_average(arr, k))
# Out:
# Moving average:  [  5.           4.66666667   5.66666667   6.66666667   9.66666667
#   28.66666667  49.33333333  72.66666667  84.          93.33333333
#  116.33333333]
